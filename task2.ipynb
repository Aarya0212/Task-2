# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds=pd.read_csv('employee_dataset_for_eda.csv')
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
#employee count as per department
sns.countplot(data=ds,x='Department',palette='Set2')
plt.title('Employee count as per department')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\7044009.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Department',palette='Set2')
# Text(0.5, 1.0, 'Employee count as per department')

# %% [markdown]
# Finance department having more employee count followed by marketing & engineering

# %%
#gender distribution
sns.countplot(data=ds,x='Gender',palette='coolwarm')
plt.title('gender distribution')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\2228344538.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Gender',palette='coolwarm')
# Text(0.5, 1.0, 'gender distribution')

# %% [markdown]
# Female employees are more than male in specified companies

# %%
#location distribution
sns.countplot(data=ds,x='Location',palette='Spectral')
plt.title('Number of employees by location')
plt.xticks(rotation=45)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\3856919800.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Location',palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# mostly employees are located in seattle followed by san franciso & new york

# %%
#age distribution
sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# employee having age 45 to 50 are more than employee having age 25 to 30

# %%
#Years_of_Experience distributiobn
sns.histplot(ds['Years_of_Experience'],bins=15,kde=True)
plt.title('Years_of_Experience')
# Out:
# Text(0.5, 1.0, 'Years_of_Experience')

# %% [markdown]
# Employee having more experience between range 2.5 to 5.0

# %%
#monthly salary distribution
sns.boxplot(data=ds,y='Monthly_Salary',color='lightblue')
plt.title('monthly salary')
# Out:
# Text(0.5, 1.0, 'monthly salary')

# %% [markdown]
# Each department has average salary in range 75,000

# %%
#Average salary by department
sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
plt.title('Average salary by department')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\1627455025.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds,x='Department',y='Monthly_Salary',estimator=np.mean,palette='viridis')
# Text(0.5, 1.0, 'Average salary by department')

# %% [markdown]
# Finance department has the average salary between 75000 to above 80000

# %%
#performane scored by department
sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
plt.title('performane scored by department')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\313833798.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds,x='Department',y='Performance_Score',palette='pastel')
# Text(0.5, 1.0, 'performane scored by department')

# %% [markdown]
# marketing department scored the maximum performance

# %%
#salary distribution by gender
sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
plt.title('salary distribution by gender')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_43320\4059869285.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds,x='Gender',y='Monthly_Salary',palette='muted')
# Text(0.5, 1.0, 'salary distribution by gender')

# %% [markdown]
# Male employee having maximum monthly salary

# %%
#correlation matrix
sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True,cmap='coolwarm')
plt.title('correlation matrix')
# Out:
# Text(0.5, 1.0, 'correlation matrix')

# %% [markdown]
# employee having less age and so that they also have leaa year of experience

# %%
#salary vc experience scatter plot
sns.scatterplot(data=ds,x='Years_of_Experience',y='Monthly_Salary',hue='Department')
